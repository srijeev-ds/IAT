# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
import dash_table
from dash.dependencies import Input, Output
import plotly.express as px

df = pd.read_csv("/Users/kennethlau/Desktop/IAT_project/IAT_2/IAT2/IAT/Datasets/nutrition/all_nutrition.csv")
df["quantity"] = 1

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
path = ["Restaurant", "Category", "Items"]

# df = px.data.tips()

# %%
df.head(10)
# Out:
#    Restaurant   Category                                      Items  \
# 0  burgerking  Breakfast           BK - Bacon, Egg & Cheese Biscuit
# 1  burgerking  Breakfast                 BK - Breakfast Burrito Jr.
# 2  burgerking  Breakfast   BK - CROISSAN’WICH® Bacon, Egg & Cheese
# 3  burgerking  Breakfast           BK - CROISSAN’WICH® Egg & Cheese
# 4  burgerking  Breakfast      BK - CROISSAN’WICH® Ham, Egg & Cheese
# 5  burgerking  Breakfast  BK - CROISSAN’WICH® Sausage, Egg & Cheese
# 6  burgerking  Breakfast        BK - French Toast Sticks (3 piece)
# 7  burgerking  Breakfast           BK - Ham, Egg, & Cheese Biscuit
# 8  burgerking  Breakfast                  BK - Hash Browns – medium
# 9  burgerking  Breakfast           BK - Pancake and Sausage platter
#
#    Cost (USD)  Calories  Protein (g)  Fat (g)  Carbs (g)  Sugar (g)  \
# 0        2.99       400         13.0     26.0         29          3
# 1        1.00       370         15.0     23.0         27          2
# 2        2.99       370         14.0     21.0         30          4
# 3        2.99       340         12.0     18.0         29          4
# 4        2.99       370         17.0     19.0         30          5
# 5        2.99       500         19.0     33.0         30          4
# 6        1.00       230          3.0     11.0         29          8
# 7        2.99       400         17.0     24.0         29          3
# 8        1.69       500          4.0     33.0         48          0
# 9        3.69       610         12.0     31.0         72         30
#
#    Sodium (g)  quantity
# 0        1.27         1
# 1        0.93         1
# 2        0.76         1
# 3        0.61         1
# 4        1.03         1
# 5        0.93         1
# 6        0.26         1
# 7        1.55         1
# 8        1.14         1
# 9        1.01         1

# %%
app.layout = html.Div(
    [
        html.H4(id="title"),
        html.Div(
            [
                dcc.Graph(
                    id="sunburst",
                    figure=px.sunburst(df, path=path, values="Cost (USD)"),
                )
            ]
        ),
        html.Div(
            [
                dash_table.DataTable(
                    id="table",
                    columns=[{"name": i, "id": i} for i in df.columns],
                    data=df.to_dict("records"),
                )
            ]
        ),
    ]
)

# %%
@app.callback(
    [Output("table", "data"), Output("title", "children")],
    [Input("sunburst", "clickData")],
)
def update_table(clickData):
    click_path = "ALL"
    root = False

    data = df.to_dict("records")
    if clickData:
        click_path = clickData["points"][0]["id"].split("/")
        selected = dict(zip(path, click_path))

        if "Items" in selected:
            dff = df[
                (df["Restaurant"] == selected["Restaurant"])
                & (df["Category"] == selected["Category"])
                & (df["Items"] == selected["Items"])
            ]
        elif "Category" in selected:
            dff = df[(df["Restaurant"] == selected["Restaurant"]) & (df["Category"] == selected["Category"])]
        else:
            dff = df[(df["Restaurant"] == selected["Restaurant"])]
            root = True
        data = dff.to_dict("records")

        # Show all data when returning to the root from an outer leaf
        percentEntry = (clickData["points"][0]).get("percentEntry")
        if root and percentEntry == 1:
            data = df.to_dict("records")
            click_path = "ALL"

    title = f"Selected from Sunburst Chart: {' '.join(click_path)}"
#     print(click_path)
    print(title)
#     print(data)
    return data, title


if __name__ == "__main__":
    app.run_server(host = '127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# Selected from Sunburst Chart: A L L
# Selected from Sunburst Chart: starbucks
# Selected from Sunburst Chart: starbucks Salad
# Selected from Sunburst Chart: starbucks Salad
# Selected from Sunburst Chart: A L L
# Selected from Sunburst Chart: chick-fil-a
# Selected from Sunburst Chart: chick-fil-a Side
# Selected from Sunburst Chart: chick-fil-a Side CFA - Waffle Potato Fries

# %%
# -*- coding: utf-8 -*-
import dash
import dash_table
from dash.dependencies import Input, Output

import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px


external_stylesheets = ["https://codepen.io/chriddyp/pen/bWLwgP.css"]

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

df = px.data.tips()

path = ["day", "time", "sex"]

app.layout = html.Div(
    [
        html.H4(id="title"),
        html.Div(
            [
                dcc.Graph(
                    id="sunburst",
                    figure=px.sunburst(df, path=path, values="total_bill"),
                )
            ]
        ),
        html.Div(
            [
                dash_table.DataTable(
                    id="table",
                    columns=[{"name": i, "id": i} for i in df.columns],
                    data=df.to_dict("records"),
                )
            ]
        ),
    ]
)


@app.callback(
    [Output("table", "data"), Output("title", "children")],
    [Input("sunburst", "clickData")],
)
def update_table(clickData):
    click_path = "ALL"
    root = False

    data = df.to_dict("records")
    if clickData:
        click_path = clickData["points"][0]["id"].split("/")
        selected = dict(zip(path, click_path))

        if "sex" in selected:
            dff = df[
                (df["day"] == selected["day"])
                & (df["time"] == selected["time"])
                & (df["sex"] == selected["sex"])
            ]
        elif "time" in selected:
            dff = df[(df["day"] == selected["day"]) & (df["time"] == selected["time"])]
        else:
            dff = df[(df["day"] == selected["day"])]
            root = True
        data = dff.to_dict("records")

        # Show all data when returning to the root from an outer leaf
        percentEntry = (clickData["points"][0]).get("percentEntry")
        if root and percentEntry == 1:
            data = df.to_dict("records")
            click_path = "ALL"

    title = f"Selected from Sunburst Chart: {' '.join(click_path)}"
#     print(click_path)
    print(title)
#     print(data)
    return data, title


if __name__ == "__main__":
    app.run_server(host = '127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# Selected from Sunburst Chart: A L L
# Selected from Sunburst Chart: Sun Dinner
# Selected from Sunburst Chart: Sun Dinner Female
# Selected from Sunburst Chart: Sun Dinner Male
# Selected from Sunburst Chart: Sun Dinner
# Selected from Sunburst Chart: A L L
# Selected from Sunburst Chart: Sat
# Selected from Sunburst Chart: A L L
# Selected from Sunburst Chart: Fri
# Selected from Sunburst Chart: A L L
