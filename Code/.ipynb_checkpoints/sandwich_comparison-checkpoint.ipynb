# %%
# importing necessary libraries
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
from dash.dependencies import Input, Output
import plotly.express as px

# %%
foodo = pd.read_csv("/Users/srijeevsarkar/Desktop/IAT/Datasets/nutrition/all_nutrition.csv")
foodo.head(10)
# Out:
#    Restaurant   Category                                      Items  \
# 0  burgerking  Breakfast           BK - Bacon, Egg & Cheese Biscuit
# 1  burgerking  Breakfast                 BK - Breakfast Burrito Jr.
# 2  burgerking  Breakfast   BK - CROISSAN’WICH® Bacon, Egg & Cheese
# 3  burgerking  Breakfast           BK - CROISSAN’WICH® Egg & Cheese
# 4  burgerking  Breakfast      BK - CROISSAN’WICH® Ham, Egg & Cheese
# 5  burgerking  Breakfast  BK - CROISSAN’WICH® Sausage, Egg & Cheese
# 6  burgerking  Breakfast        BK - French Toast Sticks (3 piece)
# 7  burgerking  Breakfast           BK - Ham, Egg, & Cheese Biscuit
# 8  burgerking  Breakfast                  BK - Hash Browns – medium
# 9  burgerking  Breakfast           BK - Pancake and Sausage platter
#
#    Cost (USD)  Calories  Protein (g)  Fat (g)  Carbs (g)  Sugar (g)  \
# 0        2.99       400         13.0     26.0         29          3
# 1        1.00       370         15.0     23.0         27          2
# 2        2.99       370         14.0     21.0         30          4
# 3        2.99       340         12.0     18.0         29          4
# 4        2.99       370         17.0     19.0         30          5
# 5        2.99       500         19.0     33.0         30          4
# 6        1.00       230          3.0     11.0         29          8
# 7        2.99       400         17.0     24.0         29          3
# 8        1.69       500          4.0     33.0         48          0
# 9        3.69       610         12.0     31.0         72         30
#
#    Sodium (g)
# 0        1.27
# 1        0.93
# 2        0.76
# 3        0.61
# 4        1.03
# 5        0.93
# 6        0.26
# 7        1.55
# 8        1.14
# 9        1.01

# %%
is_sandwich =  foodo['Category']=="Sandwich"
sando = foodo[is_sandwich]
sando
# Out:
#      Restaurant  Category                                        Items  \
# 35   burgerking  Sandwich  BK - Bacon & Cheese Crispy Chicken Sandwich
# 36   burgerking  Sandwich            BK - Bacon Cheeseburger® Sandwich
# 37   burgerking  Sandwich               BK - Bacon Double Cheeseburger
# 38   burgerking  Sandwich                     BK - Bacon King Sandwich
# 39   burgerking  Sandwich       BK - BBQ Bacon Crispy Chicken Sandwich
# ..          ...       ...                                          ...
# 387      subway  Sandwich   SW - Sweet Onion Chicken Teriyaki Sandwich
# 388      subway  Sandwich       SW - Turkey & Bacon Guacamole Sandwich
# 389      subway  Sandwich                  SW - Turkey Breast Sandwich
# 390      subway  Sandwich                 SW - Ultimate Steak Sandwich
# 391      subway  Sandwich                 SW - Veggie Delite® Sandwich
#
#      Cost (USD)  Calories  Protein (g)  Fat (g)  Carbs (g)  Sugar (g)  \
# 35         6.09       800         30.0     52.0         55          8
# 36         1.49       320         17.0     16.0         27          7
# 37         2.09       420         25.0     24.0         27          7
# 38         6.99      1150         61.0     79.0         49         10
# 39         6.09       790         28.0     49.0         60         13
# ..          ...       ...          ...      ...        ...        ...
# 387        5.29       320          4.0     52.0         16         25
# 388        8.29       780         27.0     87.0         11         49
# 389        5.29       250          3.0     41.0          6         20
# 390        7.49       600         35.0     42.0          6         31
# 391        3.49       190          2.0     39.0          6          9
#
#      Sodium (g)
# 35         1.65
# 36         0.71
# 37         0.74
# 38         2.15
# 39         1.63
# ..          ...
# 387        0.72
# 388        2.20
# 389        0.69
# 390        1.33
# 391        0.24
#
# [82 rows x 10 columns]

# %%
app = dash.Dash()

# %%
sando.Items.unique()
# Out:
# array(['BK - Bacon & Cheese Crispy Chicken Sandwich',
#        'BK - Bacon Cheeseburger® Sandwich',
#        'BK - Bacon Double Cheeseburger', 'BK - Bacon King Sandwich',
#        'BK - BBQ Bacon Crispy Chicken Sandwich',
#        'BK - Cheeseburger® Sandwich', 'BK - Chicken Nuggets- 4pc',
#        'BK - Chicken Nuggets- 8pc', 'BK - Crispy Chicken Jr.',
#        'BK - Crispy Chicken Sandwich',
#        'BK - Double Cheeseburger® Sandwich',
#        'BK - Double Whopper® Sandwich', 'BK - Hamburger® Sandwich',
#        'BK - IMPOSSIBLE Whopper® Sandwich',
#        'BK - Original Chicken Sandwich', 'BK - Spicy Crispy Chicken Jr.',
#        'BK - Spicy Crispy Chicken Sandwich',
#        'BK - Triple Whopper® Sandwich', 'BK - Whopper JR.® Sandwich',
#        'BK - Whopper® Sandwich',
#        'CFA - Chargrilled Chicken Club Sandwich',
#        'CFA - Chargrilled Chicken Cool Wrap',
#        'CFA - Chargrilled Chicken Sandwich',
#        'CFA - Chicken Caesar Cool Wrap', 'CFA - Chicken Deluxe Sandwich',
#        'CFA - Chicken Salad Sandwich', 'CFA - Chicken Sandwich',
#        'CFA - Spicy Chicken Cool Wrap',
#        'CFA - Spicy Chicken Deluxe Sandwich',
#        'CFA - Spicy Chicken Sandwich', 'McD - Bacon Clubhouse Burger',
#        'McD - Bacon Clubhouse Crispy Chicken Sandwich',
#        'McD - Bacon Clubhouse Grilled Chicken Sandwich', 'McD - Big Mac',
#        'McD - Cheeseburger', 'McD - Chicken McNuggets (10 piece)',
#        'McD - Chicken McNuggets (20 piece)',
#        'McD - Chicken McNuggets (40 piece)', 'McD - Double Cheeseburger',
#        'McD - Double Quarter Pounder with Cheese', 'McD - Filet-O-Fish',
#        'McD - Hamburger', 'McD - McChicken', 'McD - McDouble',
#        'McD - McRib', 'McD - McWrap Chicken & Bacon (Crispy Chicken)',
#        'McD - McWrap Chicken & Bacon (Grilled Chicken)',
#        'McD - McWrap Chicken & Ranch (Crispy Chicken)',
#        'McD - McWrap Chicken & Ranch (Grilled Chicken)',
#        'McD - McWrap Southwest Chicken (Crispy Chicken)',
#        'McD - McWrap Southwest Chicken (Grilled Chicken)',
#        'McD - Quarter Pounder with Cheese',
#        'SB - Chicken & Double-Smoked Bacon', 'SB - Chicken Caprese',
#        'SB - Chipotle Chicken Wrap',
#        'SB - Crispy Grilled Cheese Sandwich',
#        "SB - Everybody's Favorite - Bantam Bagel (2 Pack)",
#        'SB - Everything Bagel',
#        'SB - French Toast - Bantam Bagels (2 Pack)',
#        'SB - Ham & Swiss Panini', 'SB - Plain Bagel',
#        'SB - Sprouted Grain Vegan Bagel', 'SB - Tomato & Mozzarella',
#        'SB - Turkey Pesto Panini', 'SW - Black Forest Ham Sandwich',
#        'SW - Chicken & Bacon Ranch Melt', 'SW - Classic Tuna',
#        'SW - Cold Cut Combo Sandwich', 'SW - Ham & Jack Slider',
#        'SW - Italian Spice Slider', 'SW - Little Cheesesteak Slider',
#        'SW - Meatball Marinara Sandwich', 'SW - Roast Beef Sandwich',
#        'SW - Rotisserie-Style Chicken Sandwich',
#        'SW - Spicy Italian Sandwich', 'SW - Steak Club Sandwich',
#        'SW - Subway Club® Sandwich',
#        'SW - Sweet Onion Chicken Teriyaki Sandwich',
#        'SW - Turkey & Bacon Guacamole Sandwich',
#        'SW - Turkey Breast Sandwich', 'SW - Ultimate Steak Sandwich',
#        'SW - Veggie Delite® Sandwich'], dtype=object)

# %%
app.layout = html.Div([
    
    dcc.Dropdown(id='opt1', value=['BK - Bacon & Cheese Crispy Chicken Sandwich'], multi=False,
                 options=[{'label': x, 'value': x} for x in
                          sando.Items.unique()]),
    dcc.Dropdown(id='opt2', value=['CFA - Spicy Chicken Deluxe Sandwich'], multi=False,
                 options=[{'label': x, 'value': x} for x in
                          sando.Items.unique()]),
    dcc.Dropdown(id='opt3', value=['McD - Big Mac'], multi=False,
                 options=[{'label': x, 'value': x} for x in
                          sando.Items.unique()]),
    dcc.Dropdown(id='opt4', value=['SB - Ham & Swiss Panini'], multi=False,
                 options=[{'label': x, 'value': x} for x in
                          sando.Items.unique()]),
    dcc.Dropdown(id='opt5', value=['SW - Veggie Delite® Sandwich'], multi=False,
                 options=[{'label': x, 'value': x} for x in
                          sando.Items.unique()]),
    
    dcc.Graph(id='sando_map', figure={}),
    
    
])

# %%
nutrition=['Protein (g)', 'Fat (g)', 'Carbs (g)', 'Sugar (g)', 'Sodium (g)']

@app.callback(
    Output(component_id='sando_map', component_property='figure'),
    Input(component_id='opt1', component_property='value'),
    Input(component_id='opt2', component_property='value'),
    Input(component_id='opt3', component_property='value'),
    Input(component_id='opt4', component_property='value'),
    Input(component_id='opt5', component_property='value'),
)

def group_graph(choice1,choice2,choice3,choice4,choice5):
    
    
    a = sando[sando["Items"]==choice1]
    protein_a = a.iloc[0][5]
    fat_a = a.iloc[0][6]
    carb_a = a.iloc[0][7]
    sugar_a= a.iloc[0][8]
    sodium_a = a.iloc[0][9]
    
    b = sando[sando["Items"]==choice2]
    protein_b = b.iloc[0][5]
    fat_b = b.iloc[0][6]
    carb_b = b.iloc[0][7]
    sugar_b= b.iloc[0][8]
    sodium_b = b.iloc[0][9]
    
    c = sando[sando["Items"]==choice3]
    protein_c = c.iloc[0][5]
    fat_c = c.iloc[0][6]
    carb_c = c.iloc[0][7]
    sugar_c= c.iloc[0][8]
    sodium_c = c.iloc[0][9]
    
    d = sando[sando["Items"]==choice4]
    protein_d = d.iloc[0][5]
    fat_d = d.iloc[0][6]
    carb_d = d.iloc[0][7]
    sugar_d = d.iloc[0][8]
    sodium_d = d.iloc[0][9]
    
    e = sando[sando["Items"]==choice5]
    protein_e = e.iloc[0][5]
    fat_e = e.iloc[0][6]
    carb_e = e.iloc[0][7]
    sugar_e = e.iloc[0][8]
    sodium_e = e.iloc[0][9]

    
    sfig = go.Figure(data=[
    go.Bar(name=choice1, x=nutrition, y=[protein_a,protein_b,protein_c,protein_d,protein_e]),
    go.Bar(name=choice2, x=nutrition, y=[fat_a,fat_b,fat_c,fat_d,fat_e]),
    go.Bar(name=choice3, x=nutrition, y=[carb_a,carb_b,carb_c,carb_d,carb_e]),
    go.Bar(name=choice4, x=nutrition, y=[sugar_a,sugar_b,sugar_c,sugar_d,sugar_e]),
    go.Bar(name=choice5, x=nutrition, y=[sodium_a,sodium_b,sodium_c,sodium_d,sodium_e])
    ])
    
    sfig.update_layout(barmode='group')
    sfig.update_layout(title_text='Favourite sandwich comparison')
    return sfig

if __name__ == "__main__":
    app.run_server(host = '127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Apr/2021 17:01:23] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2021 17:01:23] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2021 17:01:23] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-7308cbd994b8>", line 15, in group_graph
#     a = sando[sando["Items"]==choice1]
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py", line 65, in new_method
#     return method(self, other)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py", line 370, in wrapper
#     res_values = comparison_op(lvalues, rvalues, op)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 224, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (82,), (1,))
# 127.0.0.1 - - [07/Apr/2021 17:01:23] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-7308cbd994b8>", line 15, in group_graph
#     a = sando[sando["Items"]==choice1]
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py", line 65, in new_method
#     return method(self, other)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py", line 370, in wrapper
#     res_values = comparison_op(lvalues, rvalues, op)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 224, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (82,), (1,))
# 127.0.0.1 - - [07/Apr/2021 17:01:25] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-7308cbd994b8>", line 15, in group_graph
#     a = sando[sando["Items"]==choice1]
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py", line 65, in new_method
#     return method(self, other)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py", line 370, in wrapper
#     res_values = comparison_op(lvalues, rvalues, op)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 224, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (82,), (1,))
# 127.0.0.1 - - [07/Apr/2021 17:01:26] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-7308cbd994b8>", line 15, in group_graph
#     a = sando[sando["Items"]==choice1]
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py", line 65, in new_method
#     return method(self, other)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py", line 370, in wrapper
#     res_values = comparison_op(lvalues, rvalues, op)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 224, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (82,), (1,))
# 127.0.0.1 - - [07/Apr/2021 17:01:29] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1078, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1009, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-7308cbd994b8>", line 43, in group_graph
#     e = sando[sando["Items"]==choice5]
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py", line 65, in new_method
#     return method(self, other)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py", line 370, in wrapper
#     res_values = comparison_op(lvalues, rvalues, op)
#   File "/Users/srijeevsarkar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 224, in comparison_op
#     raise ValueError(
# ValueError: ('Lengths must match to compare', (82,), (1,))
# 127.0.0.1 - - [07/Apr/2021 17:01:31] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [07/Apr/2021 17:01:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2021 17:03:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Apr/2021 17:03:36] "POST /_dash-update-component HTTP/1.1" 200 -
