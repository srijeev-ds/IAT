# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
import dash_table
from dash.dependencies import Input, Output
import plotly.express as px

# %%
#df = pd.read_csv("IAT_2/IAT/Datasets/nutrition/all_nutrition.csv")
df = pd.read_csv("/Users/srijeevsarkar/Desktop/IAT/Datasets/nutrition/all_nutrition.csv")
df["quantity"] = 1

# %%
df
# Out:
#      Restaurant  Category                            Items  Cost (USD)  \
# 0    burgerking  Sandwich                Whopper® Sandwich        4.19
# 1    burgerking  Sandwich         Double Whopper® Sandwich        5.29
# 2    burgerking  Sandwich         Triple Whopper® Sandwich        6.39
# 3    burgerking  Sandwich            Whopper JR.® Sandwich        2.19
# 4    burgerking  Sandwich              Bacon King Sandwich        6.99
# ..          ...       ...                              ...         ...
# 506      subway   Dessert            Oatmeal Raisin Cookie        0.60
# 507      subway   Dessert      Raspberry Cheesecake Cookie        0.60
# 508      subway   Dessert        Raspberry Lemonade Cookie        0.60
# 509      subway   Dessert                     Sugar Cookie        0.60
# 510      subway   Dessert  White Chip Macadamia Nut Cookie        0.60
#
#      Calories  Protein (g)  Fat (g)  Carbs (g)  Sugar (g)  Sodium (g)  \
# 0         660         28.0     40.0         49         11        0.98
# 1         900         48.0     58.0         49         11        1.05
# 2        1130         67.0     75.0         49         11        1.12
# 3         310         13.0     18.0         27          7        0.39
# 4        1150         61.0     79.0         49         10        2.15
# ..        ...          ...      ...        ...        ...         ...
# 506       200          8.0     30.0         16          3        0.13
# 507       200          9.0     29.0         16          2        0.12
# 508       230         11.0     31.0         20          2        0.10
# 509       230         12.0     28.0         14          2        0.13
# 510       220         11.0     28.0         17          2        0.13
#
#      quantity
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 506         1
# 507         1
# 508         1
# 509         1
# 510         1
#
# [511 rows x 11 columns]

# %%
cols = ['Restaurant']
parts = [df.groupby([col, 'Category']).quantity.sum() for col in cols]
df2 = pd.concat(parts).unstack(fill_value=0)
options1 = df["Restaurant"].unique()

# %% [markdown]
# # Top sunburst

# %%
df
path = ["Restaurant", "Category", "Items"]

# %%
app = dash.Dash(__name__)

# %%
app.layout = html.Div(
    [
        html.H4(id="title"),
        html.Div(
            [
                dcc.Graph(
                    id="sunburst",
                        style=
                        {
                        'height': 800
                        },
                    figure=px.sunburst(df, path=path, values="Cost (USD)"),
                )
            ]
        ),
    ]
)

# %%
@app.callback(
    [Output("title", "children")],
    [Input("sunburst", "clickData")],
)
def update_table(clickData):
    click_path = "ALL"
    root = False

    data = df.to_dict("records")
    if clickData:
        click_path = clickData["points"][0]["id"].split("/")
        selected = dict(zip(path, click_path))

        if "sex" in selected:
            dff = df[
                (df["Restaurant"] == selected["Restaurant"])
                & (df["Category"] == selected["Category"])
                & (df["Item"] == selected["Item"])
            ]
        elif "time" in selected:
            dff = df[(df["Restaurant"] == selected["Restaurant"]) & (df["Category"] == selected["Category"])]
        else:
            dff = df[(df["Restaurant"] == selected["Restaurant"])]
            root = True
        data = dff.to_dict("records")

        # Show all data when returning to the root from an outer leaf
        percentEntry = (clickData["points"][0]).get("percentEntry")
        if root and percentEntry == 1:
            data = df.to_dict("records")
            click_path = "ALL"

    title = f"Selected from Sunburst Chart: {' '.join(click_path)}"

    return data, title

if __name__ == "__main__":
    app.run_server(host = '127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-4ef127097865> in <module>
#      36
#      37 if __name__ == "__main__":
# ---> 38     app.run_server(host = '127.0.0.1')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dash/dash.py in run_server(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    1715             self.logger.info("Dash is running on %s://%s%s%s\n", *display_url)
#    1716
# -> 1717         self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/flask/app.py in run(self, host, port, debug, load_dotenv, **options)
#     988
#     989         try:
# --> 990             run_simple(host, port, self, **options)
#     991         finally:
#     992             # reset the first request information if the development server
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#    1050         run_with_reloader(inner, extra_files, reloader_interval, reloader_type)
#    1051     else:
# -> 1052         inner()
#    1053
#    1054
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/serving.py in inner()
#     994         except (LookupError, ValueError):
#     995             fd = None
# --> 996         srv = make_server(
#     997             hostname,
#     998             port,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/serving.py in make_server(host, port, app, threaded, processes, request_handler, passthrough_errors, ssl_context, fd)
#     845         raise ValueError("cannot have a multithreaded and multi process server.")
#     846     elif threaded:
# --> 847         return ThreadedWSGIServer(
#     848             host, port, app, request_handler, passthrough_errors, ssl_context, fd=fd
#     849         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/serving.py in __init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     738         if self.address_family == af_unix and os.path.exists(server_address):
#     739             os.unlink(server_address)
# --> 740         HTTPServer.__init__(self, server_address, handler)
#     741
#     742         self.app = app
#
# ~/opt/anaconda3/lib/python3.8/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450         if bind_and_activate:
#     451             try:
# --> 452                 self.server_bind()
#     453                 self.server_activate()
#     454             except:
#
# ~/opt/anaconda3/lib/python3.8/http/server.py in server_bind(self)
#     136     def server_bind(self):
#     137         """Override server_bind to store the server name."""
# --> 138         socketserver.TCPServer.server_bind(self)
#     139         host, port = self.server_address[:2]
#     140         self.server_name = socket.getfqdn(host)
#
# ~/opt/anaconda3/lib/python3.8/socketserver.py in server_bind(self)
#     464         if self.allow_reuse_address:
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#     468
#
# OSError: [Errno 48] Address already in use

# %%
df.to_dict("records")
# Out:
# [{'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Whopper® Sandwich',
#   'Cost (USD)': 4.19,
#   'Calories': 660,
#   'Protein (g)': 28.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 11,
#   'Sodium (g)': 0.98,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Double Whopper® Sandwich',
#   'Cost (USD)': 5.29,
#   'Calories': 900,
#   'Protein (g)': 48.0,
#   'Fat (g)': 58.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 11,
#   'Sodium (g)': 1.05,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Triple Whopper® Sandwich',
#   'Cost (USD)': 6.39,
#   'Calories': 1130,
#   'Protein (g)': 67.0,
#   'Fat (g)': 75.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 11,
#   'Sodium (g)': 1.12,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Whopper JR.® Sandwich',
#   'Cost (USD)': 2.19,
#   'Calories': 310,
#   'Protein (g)': 13.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.39,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Bacon King Sandwich',
#   'Cost (USD)': 6.99,
#   'Calories': 1150,
#   'Protein (g)': 61.0,
#   'Fat (g)': 79.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 10,
#   'Sodium (g)': 2.15,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'IMPOSSIBLE Whopper® Sandwich',
#   'Cost (USD)': 5.49,
#   'Calories': 630,
#   'Protein (g)': 25.0,
#   'Fat (g)': 34.0,
#   'Carbs (g)': 58,
#   'Sugar (g)': 12,
#   'Sodium (g)': 1.08,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Hamburger',
#   'Cost (USD)': 1.0,
#   'Calories': 240,
#   'Protein (g)': 13.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 26,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.38,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Cheeseburger',
#   'Cost (USD)': 1.0,
#   'Calories': 280,
#   'Protein (g)': 15.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.56,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Double Cheeseburger',
#   'Cost (USD)': 1.69,
#   'Calories': 390,
#   'Protein (g)': 23.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.59,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Bacon Cheeseburger',
#   'Cost (USD)': 1.49,
#   'Calories': 320,
#   'Protein (g)': 17.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.71,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Bacon Double Cheeseburger',
#   'Cost (USD)': 2.09,
#   'Calories': 420,
#   'Protein (g)': 25.0,
#   'Fat (g)': 24.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.74,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Crispy Chicken Sandwich',
#   'Cost (USD)': 4.99,
#   'Calories': 670,
#   'Protein (g)': 23.0,
#   'Fat (g)': 41.0,
#   'Carbs (g)': 54,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.08,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Crispy Chicken Sandwich',
#   'Cost (USD)': 5.69,
#   'Calories': 700,
#   'Protein (g)': 25.0,
#   'Fat (g)': 42.0,
#   'Carbs (g)': 57,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.14,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Original Chicken Sandwich',
#   'Cost (USD)': 4.49,
#   'Calories': 660,
#   'Protein (g)': 28.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 5,
#   'Sodium (g)': 1.17,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Bacon & Cheese Crispy Chicken Sandwich',
#   'Cost (USD)': 6.09,
#   'Calories': 800,
#   'Protein (g)': 30.0,
#   'Fat (g)': 52.0,
#   'Carbs (g)': 55,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.65,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'BBQ Bacon Crispy Chicken Sandwich',
#   'Cost (USD)': 6.09,
#   'Calories': 790,
#   'Protein (g)': 28.0,
#   'Fat (g)': 49.0,
#   'Carbs (g)': 60,
#   'Sugar (g)': 13,
#   'Sodium (g)': 1.63,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Crispy Chicken Jr.',
#   'Cost (USD)': 1.19,
#   'Calories': 450,
#   'Protein (g)': 12.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 34,
#   'Sugar (g)': 5,
#   'Sodium (g)': 0.78,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Crispy Chicken Jr.',
#   'Cost (USD)': 1.19,
#   'Calories': 390,
#   'Protein (g)': 12.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 37,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.74,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Nuggets- 4pc',
#   'Cost (USD)': 1.29,
#   'Calories': 170,
#   'Protein (g)': 8.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.31,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Nuggets- 8pc',
#   'Cost (USD)': 1.0,
#   'Calories': 260,
#   'Protein (g)': 12.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 16,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.47,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Salad',
#   'Items': 'Garden Chicken Salad with Crispy Chicken – no dressing',
#   'Cost (USD)': 7.09,
#   'Calories': 440,
#   'Protein (g)': 25.0,
#   'Fat (g)': 25.0,
#   'Carbs (g)': 31,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.93,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Salad',
#   'Items': 'Club Salad with Crispy Chicken – no dressing',
#   'Cost (USD)': 7.09,
#   'Calories': 540,
#   'Protein (g)': 31.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 31,
#   'Sugar (g)': 5,
#   'Sodium (g)': 1.38,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Salad',
#   'Items': 'Garden Side Salad – w/o dressing',
#   'Cost (USD)': 5.59,
#   'Calories': 60,
#   'Protein (g)': 4.0,
#   'Fat (g)': 4.0,
#   'Carbs (g)': 3,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.095,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'Onion Rings – small',
#   'Cost (USD)': 1.79,
#   'Calories': 320,
#   'Protein (g)': 3.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 41,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.84,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'Onion Rings – medium',
#   'Cost (USD)': 2.19,
#   'Calories': 410,
#   'Protein (g)': 4.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 53,
#   'Sugar (g)': 5,
#   'Sodium (g)': 1.08,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'Onion Rings – large',
#   'Cost (USD)': 2.39,
#   'Calories': 500,
#   'Protein (g)': 5.0,
#   'Fat (g)': 25.0,
#   'Carbs (g)': 64,
#   'Sugar (g)': 7,
#   'Sodium (g)': 1.31,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'French Fries – small',
#   'Cost (USD)': 1.79,
#   'Calories': 320,
#   'Protein (g)': 4.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 1,
#   'Sodium (g)': 0.3,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'French Fries – medium',
#   'Cost (USD)': 2.19,
#   'Calories': 380,
#   'Protein (g)': 4.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 58,
#   'Sugar (g)': 1,
#   'Sodium (g)': 0.36,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Side',
#   'Items': 'French Fries – large',
#   'Cost (USD)': 2.39,
#   'Calories': 430,
#   'Protein (g)': 5.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 66,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.41,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Dessert',
#   'Items': 'Soft Serve Cone',
#   'Cost (USD)': 1.0,
#   'Calories': 190,
#   'Protein (g)': 5.0,
#   'Fat (g)': 4.5,
#   'Carbs (g)': 32,
#   'Sugar (g)': 24,
#   'Sodium (g)': 0.15,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Dessert',
#   'Items': 'Soft Serve Cup',
#   'Cost (USD)': 1.0,
#   'Calories': 170,
#   'Protein (g)': 5.0,
#   'Fat (g)': 4.5,
#   'Carbs (g)': 28,
#   'Sugar (g)': 24,
#   'Sodium (g)': 0.15,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Dessert',
#   'Items': 'Sundae',
#   'Cost (USD)': 1.59,
#   'Calories': 260,
#   'Protein (g)': 5.0,
#   'Fat (g)': 5.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 43,
#   'Sodium (g)': 0.16,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Coca Cola classic® - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 210,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 58,
#   'Sugar (g)': 58,
#   'Sodium (g)': 0.05,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Coca Cola classic® - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 270,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 73,
#   'Sugar (g)': 73,
#   'Sodium (g)': 0.06,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Coca Cola classic® - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 290,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 105,
#   'Sugar (g)': 105,
#   'Sodium (g)': 0.085,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Diet Coke® - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Diet Coke® - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.085,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Diet Coke® - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.12,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sprite® - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 210,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 56,
#   'Sugar (g)': 56,
#   'Sodium (g)': 0.095,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sprite® - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 260,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 70,
#   'Sugar (g)': 70,
#   'Sodium (g)': 0.12,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sprite® - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 380,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 102,
#   'Sugar (g)': 102,
#   'Sodium (g)': 0.17,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Dr. Pepper® - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 190,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 52,
#   'Sugar (g)': 51,
#   'Sodium (g)': 0.06,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Dr. Pepper® - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 240,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 65,
#   'Sugar (g)': 64,
#   'Sodium (g)': 0.075,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Dr. Pepper® - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 350,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 94,
#   'Sugar (g)': 93,
#   'Sodium (g)': 0.105,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Barq’s® Root Beer - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 240,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 65,
#   'Sugar (g)': 65,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Barq’s® Root Beer - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 300,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 81,
#   'Sugar (g)': 81,
#   'Sodium (g)': 0.12,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Barq’s® Root Beer - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 350,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 118,
#   'Sugar (g)': 118,
#   'Sodium (g)': 0.18,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Cherry Coke® - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 220,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 61,
#   'Sugar (g)': 61,
#   'Sodium (g)': 0.055,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Cherry Coke® - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 280,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 76,
#   'Sugar (g)': 76,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Cherry Coke® - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 410,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 110,
#   'Sugar (g)': 110,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Fanta® Orange - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 230,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 62,
#   'Sugar (g)': 61,
#   'Sodium (g)': 0.06,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Fanta® Orange - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 280,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 78,
#   'Sugar (g)': 77,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Fanta® Orange - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 410,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 113,
#   'Sugar (g)': 111,
#   'Sodium (g)': 0.105,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Hi-C® Fruit Punch - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 220,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 62,
#   'Sugar (g)': 60,
#   'Sodium (g)': 0.075,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Hi-C® Fruit Punch - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 280,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 77,
#   'Sugar (g)': 75,
#   'Sodium (g)': 0.095,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Hi-C® Fruit Punch - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 410,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 111,
#   'Sugar (g)': 109,
#   'Sodium (g)': 0.135,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'MINUTE MAID® Light Lemonade - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 10,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 3,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.06,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'MINUTE MAID® Light Lemonade - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 10,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 4,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'MINUTE MAID® Light Lemonade - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 15,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.105,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sweet Tea - 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 120,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 35,
#   'Sugar (g)': 35,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sweet Tea - 20 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 160,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 49,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Sweet Tea - 29 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 240,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 71,
#   'Sugar (g)': 71,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Capri Sun® 100% Apple Juice',
#   'Cost (USD)': 1.29,
#   'Calories': 80,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 20,
#   'Sugar (g)': 20,
#   'Sodium (g)': 0.025,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'Minute Maid® Orange Juice',
#   'Cost (USD)': 1.69,
#   'Calories': 140,
#   'Protein (g)': 2.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 33,
#   'Sugar (g)': 30,
#   'Sodium (g)': 0.02,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Coffee- 12 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Coffee- 16 fl oz',
#   'Cost (USD)': 2.09,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Coffee- 20 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Decaf Coffee- 12 fl oz',
#   'Cost (USD)': 1.59,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Decaf Coffee- 16 fl oz',
#   'Cost (USD)': 1.79,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Iced Vanilla Coffee- 12 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 150,
#   'Protein (g)': 1.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 21,
#   'Sugar (g)': 21,
#   'Sodium (g)': 0.03,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Iced Vanilla Coffee- 16 fl oz',
#   'Cost (USD)': 2.89,
#   'Calories': 200,
#   'Protein (g)': 2.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 27,
#   'Sodium (g)': 0.04,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Iced Mocha Coffee- 12 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 180,
#   'Protein (g)': 2.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 25,
#   'Sodium (g)': 0.04,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Iced Mocha Coffee- 16 fl oz',
#   'Cost (USD)': 2.89,
#   'Calories': 240,
#   'Protein (g)': 2.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 35,
#   'Sugar (g)': 32,
#   'Sodium (g)': 0.055,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Mocha Frappe- 12 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 300,
#   'Protein (g)': 7.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 50,
#   'Sugar (g)': 41,
#   'Sodium (g)': 0.2,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Mocha Frappe- 16 fl oz',
#   'Cost (USD)': 2.89,
#   'Calories': 400,
#   'Protein (g)': 9.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 68,
#   'Sugar (g)': 58,
#   'Sodium (g)': 0.27,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Caramel Frappe- 12 fl oz',
#   'Cost (USD)': 2.39,
#   'Calories': 300,
#   'Protein (g)': 7.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 50,
#   'Sugar (g)': 41,
#   'Sodium (g)': 0.21,
#   'quantity': 1},
#  {'Restaurant': 'burgerking',
#   'Category': 'Drink',
#   'Items': 'BK® Café Caramel Frappe- 16 fl oz',
#   'Cost (USD)': 2.89,
#   'Calories': 400,
#   'Protein (g)': 9.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 68,
#   'Sugar (g)': 56,
#   'Sodium (g)': 0.28,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'CROISSAN’WICH® Egg & Cheese',
#   'Cost (USD)': 2.99,
#   'Calories': 340,
#   'Protein (g)': 12.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.61,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'CROISSAN’WICH® Sausage, Egg & Cheese',
#   'Cost (USD)': 2.99,
#   'Calories': 500,
#   'Protein (g)': 19.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.93,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'CROISSAN’WICH® Ham, Egg & Cheese',
#   'Cost (USD)': 2.99,
#   'Calories': 370,
#   'Protein (g)': 17.0,
#   'Fat (g)': 19.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 5,
#   'Sodium (g)': 1.03,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'CROISSAN’WICH® Bacon, Egg & Cheese',
#   'Cost (USD)': 2.99,
#   'Calories': 370,
#   'Protein (g)': 14.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.76,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Ham, Egg, & Cheese Biscuit',
#   'Cost (USD)': 2.99,
#   'Calories': 400,
#   'Protein (g)': 17.0,
#   'Fat (g)': 24.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.55,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Sausage, Egg, & Cheese Biscuit',
#   'Cost (USD)': 2.99,
#   'Calories': 530,
#   'Protein (g)': 19.0,
#   'Fat (g)': 38.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.44,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Biscuit',
#   'Cost (USD)': 2.99,
#   'Calories': 400,
#   'Protein (g)': 13.0,
#   'Fat (g)': 26.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.27,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Biscuit',
#   'Cost (USD)': 1.0,
#   'Calories': 420,
#   'Protein (g)': 12.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 28,
#   'Sugar (g)': 2,
#   'Sodium (g)': 1.05,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Breakfast Burrito Jr.',
#   'Cost (USD)': 1.0,
#   'Calories': 370,
#   'Protein (g)': 15.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.93,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Pancake and Sausage platter',
#   'Cost (USD)': 3.69,
#   'Calories': 610,
#   'Protein (g)': 12.0,
#   'Fat (g)': 31.0,
#   'Carbs (g)': 72,
#   'Sugar (g)': 30,
#   'Sodium (g)': 1.01,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Hash Browns – small',
#   'Cost (USD)': 1.0,
#   'Calories': 250,
#   'Protein (g)': 2.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 24,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.58,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Hash Browns – medium',
#   'Cost (USD)': 1.69,
#   'Calories': 500,
#   'Protein (g)': 4.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 0,
#   'Sodium (g)': 1.14,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Hash Browns – large',
#   'Cost (USD)': 1.89,
#   'Calories': 670,
#   'Protein (g)': 5.0,
#   'Fat (g)': 44.0,
#   'Carbs (g)': 65,
#   'Sugar (g)': 0,
#   'Sodium (g)': 1.53,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'French Toast Sticks (3 piece)',
#   'Cost (USD)': 1.0,
#   'Calories': 230,
#   'Protein (g)': 3.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 8,
#   'Sodium (g)': 0.26,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'French Toast Sticks (5 piece)',
#   'Cost (USD)': 1.99,
#   'Calories': 380,
#   'Protein (g)': 5.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 13,
#   'Sodium (g)': 0.43,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Biscuit',
#   'Cost (USD)': 3.09,
#   'Calories': 500,
#   'Protein (g)': 21.0,
#   'Fat (g)': 27.0,
#   'Carbs (g)': 43,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.37,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Biscuit',
#   'Cost (USD)': 1.09,
#   'Calories': 310,
#   'Protein (g)': 5.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 41,
#   'Sugar (g)': 9,
#   'Sodium (g)': 0.7,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Chicken Biscuit',
#   'Cost (USD)': 2.69,
#   'Calories': 440,
#   'Protein (g)': 17.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 47,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.24,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Chicken Breakfast Burrito',
#   'Cost (USD)': 3.95,
#   'Calories': 450,
#   'Protein (g)': 24.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 43,
#   'Sugar (g)': 11,
#   'Sodium (g)': 0.99,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Chicken, Egg & Cheese Bagel',
#   'Cost (USD)': 3.99,
#   'Calories': 480,
#   'Protein (g)': 29.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 49,
#   'Sugar (g)': 12,
#   'Sodium (g)': 1.23,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Biscuit',
#   'Cost (USD)': 2.69,
#   'Calories': 590,
#   'Protein (g)': 16.0,
#   'Fat (g)': 41.0,
#   'Carbs (g)': 42,
#   'Sugar (g)': 9,
#   'Sodium (g)': 1.25,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Breakfast Burrito',
#   'Cost (USD)': 3.55,
#   'Calories': 510,
#   'Protein (g)': 23.0,
#   'Fat (g)': 29.0,
#   'Carbs (g)': 40,
#   'Sugar (g)': 11,
#   'Sodium (g)': 0.97,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Yogurt Parfait',
#   'Cost (USD)': 2.45,
#   'Calories': 230,
#   'Protein (g)': 6.0,
#   'Fat (g)': 3.0,
#   'Carbs (g)': 44,
#   'Sugar (g)': 15,
#   'Sodium (g)': 0.06,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Yogurt Parfait with Chocolate Cookie Crumbs',
#   'Cost (USD)': 2.95,
#   'Calories': 240,
#   'Protein (g)': 7.0,
#   'Fat (g)': 5.0,
#   'Carbs (g)': 47,
#   'Sugar (g)': 23,
#   'Sodium (g)': 0.075,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Breakfast',
#   'Items': 'Yogurt Parfait with Granola',
#   'Cost (USD)': 2.95,
#   'Calories': 290,
#   'Protein (g)': 7.0,
#   'Fat (g)': 5.0,
#   'Carbs (g)': 54,
#   'Sugar (g)': 21,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chargrilled Chicken Club Sandwich',
#   'Cost (USD)': 5.59,
#   'Calories': 410,
#   'Protein (g)': 37.0,
#   'Fat (g)': 12.0,
#   'Carbs (g)': 39,
#   'Sugar (g)': 16,
#   'Sodium (g)': 1.46,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chargrilled Chicken Sandwich',
#   'Cost (USD)': 5.59,
#   'Calories': 300,
#   'Protein (g)': 29.0,
#   'Fat (g)': 4.0,
#   'Carbs (g)': 38,
#   'Sugar (g)': 17,
#   'Sodium (g)': 1.12,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Side',
#   'Items': 'Chick-n-Strips: 4 count',
#   'Cost (USD)': 4.39,
#   'Calories': 500,
#   'Protein (g)': 47.0,
#   'Fat (g)': 24.0,
#   'Carbs (g)': 24,
#   'Sugar (g)': 21,
#   'Sodium (g)': 1.63,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Deluxe Sandwich',
#   'Cost (USD)': 3.65,
#   'Calories': 500,
#   'Protein (g)': 35.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 43,
#   'Sugar (g)': 18,
#   'Sodium (g)': 1.63,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Salad Sandwich',
#   'Cost (USD)': 3.99,
#   'Calories': 500,
#   'Protein (g)': 29.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 52,
#   'Sugar (g)': 14,
#   'Sodium (g)': 1.24,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Sandwich',
#   'Cost (USD)': 3.05,
#   'Calories': 430,
#   'Protein (g)': 31.0,
#   'Fat (g)': 17.0,
#   'Carbs (g)': 39,
#   'Sugar (g)': 14,
#   'Sodium (g)': 1.37,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Side',
#   'Items': 'Nuggets: 12-count',
#   'Cost (USD)': 4.45,
#   'Calories': 400,
#   'Protein (g)': 42.0,
#   'Fat (g)': 17.0,
#   'Carbs (g)': 18,
#   'Sugar (g)': 19,
#   'Sodium (g)': 1.48,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Chicken Deluxe Sandwich',
#   'Cost (USD)': 3.89,
#   'Calories': 580,
#   'Protein (g)': 36.0,
#   'Fat (g)': 27.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 13,
#   'Sodium (g)': 1.88,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Chicken Sandwich',
#   'Cost (USD)': 3.29,
#   'Calories': 490,
#   'Protein (g)': 31.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 46,
#   'Sugar (g)': 58,
#   'Sodium (g)': 1.73,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Chocolate Milkshake:Large',
#   'Cost (USD)': 3.15,
#   'Calories': 750,
#   'Protein (g)': 16.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 113,
#   'Sugar (g)': 90,
#   'Sodium (g)': 0.52,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Cookie & Cream Milkshake:Large',
#   'Cost (USD)': 3.15,
#   'Calories': 700,
#   'Protein (g)': 17.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 100,
#   'Sugar (g)': 92,
#   'Sodium (g)': 0.55,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Icecream:cone',
#   'Cost (USD)': 1.65,
#   'Calories': 170,
#   'Protein (g)': 5.0,
#   'Fat (g)': 4.0,
#   'Carbs (g)': 31,
#   'Sugar (g)': 31,
#   'Sodium (g)': 0.115,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Peach Milkshake: Large',
#   'Cost (USD)': 3.15,
#   'Calories': 850,
#   'Protein (g)': 15.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 153,
#   'Sugar (g)': 28,
#   'Sodium (g)': 0.54,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Straw berry Milkshake: Large',
#   'Cost (USD)': 3.15,
#   'Calories': 770,
#   'Protein (g)': 16.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 118,
#   'Sugar (g)': 28,
#   'Sodium (g)': 0.53,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Dessert',
#   'Items': 'Vanilla Milkshake: Large',
#   'Cost (USD)': 3.15,
#   'Calories': 660,
#   'Protein (g)': 16.0,
#   'Fat (g)': 27.0,
#   'Carbs (g)': 91,
#   'Sugar (g)': 90,
#   'Sodium (g)': 0.51,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': '100% Colombian Coffee: Large',
#   'Cost (USD)': 2.35,
#   'Calories': 5,
#   'Protein (g)': 1.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 67,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Chocolate Milk',
#   'Cost (USD)': 1.19,
#   'Calories': 160,
#   'Protein (g)': 6.0,
#   'Fat (g)': 2.0,
#   'Carbs (g)': 21,
#   'Sugar (g)': 54,
#   'Sodium (g)': 0.19,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Coca-Cola: Large',
#   'Cost (USD)': 1.85,
#   'Calories': 250,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 69,
#   'Sugar (g)': 102,
#   'Sodium (g)': 0.025,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Dasani Bottled Water',
#   'Cost (USD)': 1.59,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Diet Coke: Large',
#   'Cost (USD)': 1.85,
#   'Calories': 5,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Diet Lemonade: Large',
#   'Cost (USD)': 1.85,
#   'Calories': 30,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.015,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Dr. Pepper: Larger',
#   'Cost (USD)': 1.85,
#   'Calories': 260,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 70,
#   'Sugar (g)': 126,
#   'Sodium (g)': 0.09,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Iced Tea- Sweetened: Large',
#   'Cost (USD)': 1.85,
#   'Calories': 220,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 57,
#   'Sugar (g)': 157,
#   'Sodium (g)': 0.015,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Iced Tea- Unsweetened: Large',
#   'Cost (USD)': 1.85,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 120,
#   'Sodium (g)': 0.02,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Lemonade: Large',
#   'Cost (USD)': 1.98,
#   'Calories': 350,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 92,
#   'Sugar (g)': 90,
#   'Sodium (g)': 0.015,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Milk',
#   'Cost (USD)': 1.19,
#   'Calories': 110,
#   'Protein (g)': 7.0,
#   'Fat (g)': 4.0,
#   'Carbs (g)': 12,
#   'Sugar (g)': 52,
#   'Sodium (g)': 0.115,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Minute Maid Apple Juice Box',
#   'Cost (USD)': 1.09,
#   'Calories': 100,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 23,
#   'Sugar (g)': 70,
#   'Sodium (g)': 0.015,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Drink',
#   'Items': 'Orange Juice',
#   'Cost (USD)': 2.15,
#   'Calories': 140,
#   'Protein (g)': 2.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 33,
#   'Sugar (g)': 65,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Chargrilled & Fruit Salad',
#   'Cost (USD)': 8.19,
#   'Calories': 230,
#   'Protein (g)': 22.0,
#   'Fat (g)': 6.0,
#   'Carbs (g)': 23,
#   'Sugar (g)': 15,
#   'Sodium (g)': 0.65,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Chargrilled Chicken Garden Salad',
#   'Cost (USD)': 8.19,
#   'Calories': 180,
#   'Protein (g)': 22.0,
#   'Fat (g)': 6.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.65,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Chick-n-Strip Salad',
#   'Cost (USD)': 8.19,
#   'Calories': 470,
#   'Protein (g)': 41.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.34,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Garlic and Butter Croutons',
#   'Cost (USD)': 6.19,
#   'Calories': 60,
#   'Protein (g)': 1.0,
#   'Fat (g)': 2.0,
#   'Carbs (g)': 9,
#   'Sugar (g)': 15,
#   'Sodium (g)': 0.15,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Southwest Chargrilled Salad',
#   'Cost (USD)': 8.19,
#   'Calories': 240,
#   'Protein (g)': 26.0,
#   'Fat (g)': 9.0,
#   'Carbs (g)': 18,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.82,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chargrilled Chicken Cool Wrap',
#   'Cost (USD)': 5.19,
#   'Calories': 410,
#   'Protein (g)': 33.0,
#   'Fat (g)': 12.0,
#   'Carbs (g)': 50,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.3,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Chicken Caesar Cool Wrap',
#   'Cost (USD)': 5.19,
#   'Calories': 460,
#   'Protein (g)': 39.0,
#   'Fat (g)': 15.0,
#   'Carbs (g)': 47,
#   'Sugar (g)': 10,
#   'Sodium (g)': 1.52,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Chicken Cool Wrap',
#   'Cost (USD)': 5.19,
#   'Calories': 410,
#   'Protein (g)': 35.0,
#   'Fat (g)': 12.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 13,
#   'Sodium (g)': 1.38,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Chicken Salad Cup',
#   'Cost (USD)': 5.15,
#   'Calories': 350,
#   'Protein (g)': 27.0,
#   'Fat (g)': 24.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 4,
#   'Sodium (g)': 1.1,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Fruit Cup: large',
#   'Cost (USD)': 4.25,
#   'Calories': 100,
#   'Protein (g)': 1.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 10,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Salad',
#   'Items': 'Hearty Breast of Chicken Soup: large',
#   'Cost (USD)': 8.35,
#   'Calories': 220,
#   'Protein (g)': 12.0,
#   'Fat (g)': 6.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 5,
#   'Sodium (g)': 1.76,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Side',
#   'Items': 'Side Salad',
#   'Cost (USD)': 2.89,
#   'Calories': 70,
#   'Protein (g)': 5.0,
#   'Fat (g)': 5.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.11,
#   'quantity': 1},
#  {'Restaurant': 'chick-fil-a',
#   'Category': 'Side',
#   'Items': 'Waffle Potato Fries: large',
#   'Cost (USD)': 1.85,
#   'Calories': 430,
#   'Protein (g)': 5.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 50,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.21,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Egg McMuffin',
#   'Cost (USD)': 2.79,
#   'Calories': 300,
#   'Protein (g)': 17.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 31,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.75,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Egg White Delight',
#   'Cost (USD)': 2.79,
#   'Calories': 250,
#   'Protein (g)': 18.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.77,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage McMuffin',
#   'Cost (USD)': 2.79,
#   'Calories': 370,
#   'Protein (g)': 14.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.78,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage McMuffin with Egg',
#   'Cost (USD)': 2.99,
#   'Calories': 450,
#   'Protein (g)': 21.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.86,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage McMuffin with Egg Whites',
#   'Cost (USD)': 2.79,
#   'Calories': 400,
#   'Protein (g)': 21.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 30,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.88,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Steak & Egg McMuffin',
#   'Cost (USD)': 3.99,
#   'Calories': 430,
#   'Protein (g)': 26.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 31,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.96,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)',
#   'Cost (USD)': 3.19,
#   'Calories': 460,
#   'Protein (g)': 19.0,
#   'Fat (g)': 26.0,
#   'Carbs (g)': 38,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.3,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#   'Cost (USD)': 3.19,
#   'Calories': 410,
#   'Protein (g)': 20.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 36,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.3,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Biscuit (Regular Biscuit)',
#   'Cost (USD)': 2.79,
#   'Calories': 430,
#   'Protein (g)': 11.0,
#   'Fat (g)': 27.0,
#   'Carbs (g)': 34,
#   'Sugar (g)': 2,
#   'Sodium (g)': 1.08,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Biscuit with Egg (Regular Biscuit)',
#   'Cost (USD)': 2.99,
#   'Calories': 510,
#   'Protein (g)': 18.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 36,
#   'Sugar (g)': 2,
#   'Sodium (g)': 1.17,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Southern Style Chicken Biscuit (Regular Biscuit)',
#   'Cost (USD)': 2.99,
#   'Calories': 410,
#   'Protein (g)': 17.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 41,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.18,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese McGriddles',
#   'Cost (USD)': 2.79,
#   'Calories': 460,
#   'Protein (g)': 19.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 15,
#   'Sodium (g)': 1.25,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese McGriddles with Egg Whites',
#   'Cost (USD)': 3.29,
#   'Calories': 400,
#   'Protein (g)': 20.0,
#   'Fat (g)': 15.0,
#   'Carbs (g)': 47,
#   'Sugar (g)': 16,
#   'Sodium (g)': 1.25,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage McGriddles',
#   'Cost (USD)': 2.79,
#   'Calories': 420,
#   'Protein (g)': 11.0,
#   'Fat (g)': 22.0,
#   'Carbs (g)': 44,
#   'Sugar (g)': 15,
#   'Sodium (g)': 1.03,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage, Egg & Cheese McGriddles',
#   'Cost (USD)': 2.79,
#   'Calories': 550,
#   'Protein (g)': 20.0,
#   'Fat (g)': 31.0,
#   'Carbs (g)': 48,
#   'Sugar (g)': 15,
#   'Sodium (g)': 1.32,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage, Egg & Cheese McGriddles with Egg Whites',
#   'Cost (USD)': 3.29,
#   'Calories': 500,
#   'Protein (g)': 21.0,
#   'Fat (g)': 26.0,
#   'Carbs (g)': 46,
#   'Sugar (g)': 15,
#   'Sodium (g)': 1.32,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Bagel',
#   'Cost (USD)': 2.79,
#   'Calories': 620,
#   'Protein (g)': 30.0,
#   'Fat (g)': 31.0,
#   'Carbs (g)': 57,
#   'Sugar (g)': 7,
#   'Sodium (g)': 1.48,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese Bagel with Egg Whites',
#   'Cost (USD)': 3.29,
#   'Calories': 570,
#   'Protein (g)': 30.0,
#   'Fat (g)': 25.0,
#   'Carbs (g)': 55,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.48,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Steak, Egg & Cheese Bagel',
#   'Cost (USD)': 3.29,
#   'Calories': 670,
#   'Protein (g)': 33.0,
#   'Fat (g)': 35.0,
#   'Carbs (g)': 56,
#   'Sugar (g)': 7,
#   'Sodium (g)': 1.51,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Big Breakfast (Regular Biscuit)',
#   'Cost (USD)': 3.69,
#   'Calories': 740,
#   'Protein (g)': 28.0,
#   'Fat (g)': 48.0,
#   'Carbs (g)': 51,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.56,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Big Breakfast (Large Biscuit)',
#   'Cost (USD)': 5.49,
#   'Calories': 800,
#   'Protein (g)': 28.0,
#   'Fat (g)': 52.0,
#   'Carbs (g)': 56,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.68,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Big Breakfast with Egg Whites (Regular Biscuit)',
#   'Cost (USD)': 5.49,
#   'Calories': 640,
#   'Protein (g)': 26.0,
#   'Fat (g)': 37.0,
#   'Carbs (g)': 50,
#   'Sugar (g)': 3,
#   'Sodium (g)': 1.59,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Big Breakfast with Hotcakes (Regular Biscuit)',
#   'Cost (USD)': 5.49,
#   'Calories': 1090,
#   'Protein (g)': 36.0,
#   'Fat (g)': 56.0,
#   'Carbs (g)': 111,
#   'Sugar (g)': 17,
#   'Sodium (g)': 2.15,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Big Breakfast with Hotcakes and Egg Whites (Regular Biscuit)',
#   'Cost (USD)': 5.49,
#   'Calories': 990,
#   'Protein (g)': 35.0,
#   'Fat (g)': 46.0,
#   'Carbs (g)': 110,
#   'Sugar (g)': 17,
#   'Sodium (g)': 2.17,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Hotcakes',
#   'Cost (USD)': 2.49,
#   'Calories': 350,
#   'Protein (g)': 8.0,
#   'Fat (g)': 9.0,
#   'Carbs (g)': 60,
#   'Sugar (g)': 14,
#   'Sodium (g)': 0.59,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Hotcakes and Sausage',
#   'Cost (USD)': 3.19,
#   'Calories': 520,
#   'Protein (g)': 15.0,
#   'Fat (g)': 24.0,
#   'Carbs (g)': 61,
#   'Sugar (g)': 14,
#   'Sodium (g)': 0.93,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Breakfast',
#   'Items': 'Sausage Burrito',
#   'Cost (USD)': 2.39,
#   'Calories': 300,
#   'Protein (g)': 12.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 26,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.79,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Big Mac',
#   'Cost (USD)': 3.99,
#   'Calories': 530,
#   'Protein (g)': 24.0,
#   'Fat (g)': 27.0,
#   'Carbs (g)': 47,
#   'Sugar (g)': 9,
#   'Sodium (g)': 0.96,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Quarter Pounder with Cheese',
#   'Cost (USD)': 3.79,
#   'Calories': 520,
#   'Protein (g)': 30.0,
#   'Fat (g)': 26.0,
#   'Carbs (g)': 41,
#   'Sugar (g)': 10,
#   'Sodium (g)': 1.1,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Double Quarter Pounder with Cheese',
#   'Cost (USD)': 4.79,
#   'Calories': 750,
#   'Protein (g)': 48.0,
#   'Fat (g)': 43.0,
#   'Carbs (g)': 42,
#   'Sugar (g)': 10,
#   'Sodium (g)': 1.28,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Hamburger',
#   'Cost (USD)': 0.89,
#   'Calories': 240,
#   'Protein (g)': 12.0,
#   'Fat (g)': 8.0,
#   'Carbs (g)': 32,
#   'Sugar (g)': 6,
#   'Sodium (g)': 0.48,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Cheeseburger',
#   'Cost (USD)': 1.0,
#   'Calories': 290,
#   'Protein (g)': 15.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 33,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.68,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Double Cheeseburger',
#   'Cost (USD)': 2.0,
#   'Calories': 430,
#   'Protein (g)': 24.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 35,
#   'Sugar (g)': 7,
#   'Sodium (g)': 1.04,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Bacon Clubhouse Burger',
#   'Cost (USD)': 4.49,
#   'Calories': 720,
#   'Protein (g)': 39.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 51,
#   'Sugar (g)': 14,
#   'Sodium (g)': 1.47,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'McDouble',
#   'Cost (USD)': 1.19,
#   'Calories': 380,
#   'Protein (g)': 22.0,
#   'Fat (g)': 17.0,
#   'Carbs (g)': 34,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.84,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'McRib',
#   'Cost (USD)': 3.69,
#   'Calories': 500,
#   'Protein (g)': 22.0,
#   'Fat (g)': 26.0,
#   'Carbs (g)': 44,
#   'Sugar (g)': 11,
#   'Sodium (g)': 0.98,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Bacon Clubhouse Crispy Chicken Sandwich',
#   'Cost (USD)': 4.49,
#   'Calories': 750,
#   'Protein (g)': 36.0,
#   'Fat (g)': 38.0,
#   'Carbs (g)': 65,
#   'Sugar (g)': 16,
#   'Sodium (g)': 1.72,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Bacon Clubhouse Grilled Chicken Sandwich',
#   'Cost (USD)': 4.49,
#   'Calories': 590,
#   'Protein (g)': 40.0,
#   'Fat (g)': 25.0,
#   'Carbs (g)': 51,
#   'Sugar (g)': 14,
#   'Sodium (g)': 1.56,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'McChicken',
#   'Cost (USD)': 1.75,
#   'Calories': 360,
#   'Protein (g)': 14.0,
#   'Fat (g)': 16.0,
#   'Carbs (g)': 40,
#   'Sugar (g)': 5,
#   'Sodium (g)': 0.8,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Chicken & Bacon (Crispy Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 630,
#   'Protein (g)': 32.0,
#   'Fat (g)': 32.0,
#   'Carbs (g)': 56,
#   'Sugar (g)': 7,
#   'Sodium (g)': 1.54,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Chicken & Bacon (Grilled Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 480,
#   'Protein (g)': 36.0,
#   'Fat (g)': 19.0,
#   'Carbs (g)': 42,
#   'Sugar (g)': 6,
#   'Sodium (g)': 1.37,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Chicken & Ranch (Crispy Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 610,
#   'Protein (g)': 27.0,
#   'Fat (g)': 31.0,
#   'Carbs (g)': 56,
#   'Sugar (g)': 8,
#   'Sodium (g)': 1.34,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Chicken & Ranch (Grilled Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 450,
#   'Protein (g)': 30.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 42,
#   'Sugar (g)': 6,
#   'Sodium (g)': 1.17,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Southwest Chicken (Crispy Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 670,
#   'Protein (g)': 27.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 68,
#   'Sugar (g)': 12,
#   'Sodium (g)': 1.48,
#   'quantity': 1},
#  {'Restaurant': 'mcdonalds',
#   'Category': 'Sandwich',
#   'Items': 'Premium McWrap Southwest Chicken (Grilled Chicken)',
#   'Cost (USD)': 4.39,
#   'Calories': 520,
#   'Protein (g)': 31.0,
#   'Fat (g)': 20.0,
#   'Carbs (g)': 55,
#   'Sugar (g)': 10,
#   'Sodium (g)': 1.32,
# ...
#   'Category': 'Drink',
#   'Items': 'Matcha Green Tea Latte',
#   'Cost (USD)': 3.25,
#   'Calories': 240,
#   'Protein (g)': 7.0,
#   'Fat (g)': 34.0,
#   'Carbs (g)': 32,
#   'Sugar (g)': 12,
#   'Sodium (g)': 0.16,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Matcha Lemonade',
#   'Cost (USD)': 3.25,
#   'Calories': 120,
#   'Protein (g)': 0.0,
#   'Fat (g)': 29.0,
#   'Carbs (g)': 27,
#   'Sugar (g)': 1,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Mint Majesty™ Herbal Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Peach Tranquility® Herbal Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Rev Up Wellness Brewed Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Royal English Breakfast Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Royal English Breakfast Tea Latte',
#   'Cost (USD)': 3.25,
#   'Calories': 150,
#   'Protein (g)': 4.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 21,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.105,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Chai Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Earl Grey Brewed Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 0,
#   'Protein (g)': 0.0,
#   'Fat (g)': 0.0,
#   'Carbs (g)': 0,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.0,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® London Fog Tea Latte',
#   'Cost (USD)': 3.25,
#   'Calories': 180,
#   'Protein (g)': 4.0,
#   'Fat (g)': 29.0,
#   'Carbs (g)': 29,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.105,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Black Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 45,
#   'Protein (g)': 0.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Black Tea Lemonade',
#   'Cost (USD)': 3.25,
#   'Calories': 90,
#   'Protein (g)': 0.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 22,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Green Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 45,
#   'Protein (g)': 0.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Green Tea Lemonade',
#   'Cost (USD)': 3.25,
#   'Calories': 90,
#   'Protein (g)': 0.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 22,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Passion Tango™ Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 45,
#   'Protein (g)': 0.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced Passion Tango™ Tea Lemonade',
#   'Cost (USD)': 3.25,
#   'Calories': 90,
#   'Protein (g)': 0.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 22,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced White Tea',
#   'Cost (USD)': 3.25,
#   'Calories': 45,
#   'Protein (g)': 0.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Teavana® Shaken Iced White Tea Lemonade',
#   'Cost (USD)': 3.25,
#   'Calories': 90,
#   'Protein (g)': 0.0,
#   'Fat (g)': 23.0,
#   'Carbs (g)': 22,
#   'Sugar (g)': 0,
#   'Sodium (g)': 0.01,
#   'quantity': 1},
#  {'Restaurant': 'starbucks',
#   'Category': 'Drink',
#   'Items': 'Iced Teavana® London Fog Tea Latte',
#   'Cost (USD)': 3.25,
#   'Calories': 140,
#   'Protein (g)': 2.5,
#   'Fat (g)': 25.0,
#   'Carbs (g)': 25,
#   'Sugar (g)': 4,
#   'Sodium (g)': 0.07,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Black Forest Ham',
#   'Cost (USD)': 4.99,
#   'Calories': 260,
#   'Protein (g)': 4.0,
#   'Fat (g)': 42.0,
#   'Carbs (g)': 8,
#   'Sugar (g)': 18,
#   'Sodium (g)': 0.72,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Chicken & Bacon Ranch Melt',
#   'Cost (USD)': 6.29,
#   'Calories': 530,
#   'Protein (g)': 26.0,
#   'Fat (g)': 41.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 36,
#   'Sodium (g)': 1.1,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Classic Tuna',
#   'Cost (USD)': 5.29,
#   'Calories': 450,
#   'Protein (g)': 25.0,
#   'Fat (g)': 38.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.61,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Cold Cut Combo',
#   'Cost (USD)': 3.99,
#   'Calories': 320,
#   'Protein (g)': 12.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 16,
#   'Sodium (g)': 1.06,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Meatball Marinara',
#   'Cost (USD)': 4.99,
#   'Calories': 420,
#   'Protein (g)': 18.0,
#   'Fat (g)': 47.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 19,
#   'Sodium (g)': 1.04,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Ham & Jack Slider',
#   'Cost (USD)': 1.89,
#   'Calories': 150,
#   'Protein (g)': 4.5,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 1,
#   'Sugar (g)': 8,
#   'Sodium (g)': 0.47,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Italian Spice Slider',
#   'Cost (USD)': 1.89,
#   'Calories': 230,
#   'Protein (g)': 14.0,
#   'Fat (g)': 18.0,
#   'Carbs (g)': 2,
#   'Sugar (g)': 8,
#   'Sodium (g)': 0.69,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Little Cheesesteak Slider',
#   'Cost (USD)': 2.39,
#   'Calories': 170,
#   'Protein (g)': 7.0,
#   'Fat (g)': 19.0,
#   'Carbs (g)': 2,
#   'Sugar (g)': 7,
#   'Sodium (g)': 0.43,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Steak Club',
#   'Cost (USD)': 7.29,
#   'Calories': 490,
#   'Protein (g)': 25.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 27,
#   'Sodium (g)': 1.33,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Ultimate Steak',
#   'Cost (USD)': 7.49,
#   'Calories': 600,
#   'Protein (g)': 35.0,
#   'Fat (g)': 42.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 31,
#   'Sodium (g)': 1.33,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Roast Beef',
#   'Cost (USD)': 6.29,
#   'Calories': 280,
#   'Protein (g)': 4.5,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 25,
#   'Sodium (g)': 0.63,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Rotisserie-Style Chicken',
#   'Cost (USD)': 5.29,
#   'Calories': 310,
#   'Protein (g)': 6.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 28,
#   'Sodium (g)': 0.52,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Spicy Italian',
#   'Cost (USD)': 5.99,
#   'Calories': 450,
#   'Protein (g)': 24.0,
#   'Fat (g)': 40.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 18,
#   'Sodium (g)': 1.24,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Subway Club®',
#   'Cost (USD)': 6.29,
#   'Calories': 280,
#   'Protein (g)': 4.0,
#   'Fat (g)': 41.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 25,
#   'Sodium (g)': 0.78,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Sweet Onion Chicken Teriyaki',
#   'Cost (USD)': 5.29,
#   'Calories': 320,
#   'Protein (g)': 4.0,
#   'Fat (g)': 52.0,
#   'Carbs (g)': 16,
#   'Sugar (g)': 25,
#   'Sodium (g)': 0.72,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Turkey & Bacon Guacamole',
#   'Cost (USD)': 8.29,
#   'Calories': 780,
#   'Protein (g)': 27.0,
#   'Fat (g)': 87.0,
#   'Carbs (g)': 11,
#   'Sugar (g)': 49,
#   'Sodium (g)': 2.2,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Turkey Breast',
#   'Cost (USD)': 5.29,
#   'Calories': 250,
#   'Protein (g)': 3.0,
#   'Fat (g)': 41.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 20,
#   'Sodium (g)': 0.69,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Sandwich',
#   'Items': 'Veggie Delite®',
#   'Cost (USD)': 3.49,
#   'Calories': 190,
#   'Protein (g)': 2.0,
#   'Fat (g)': 39.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 9,
#   'Sodium (g)': 0.24,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Black Forest Ham',
#   'Cost (USD)': 7.99,
#   'Calories': 120,
#   'Protein (g)': 3.0,
#   'Fat (g)': 12.0,
#   'Carbs (g)': 6,
#   'Sugar (g)': 13,
#   'Sodium (g)': 0.55,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Chicken & Bacon Ranch',
#   'Cost (USD)': 8.78,
#   'Calories': 460,
#   'Protein (g)': 33.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 32,
#   'Sodium (g)': 1.0,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Cold Cut Combo',
#   'Cost (USD)': 6.49,
#   'Calories': 180,
#   'Protein (g)': 11.0,
#   'Fat (g)': 12.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 12,
#   'Sodium (g)': 0.83,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Meatball Marinara',
#   'Cost (USD)': 6.48,
#   'Calories': 290,
#   'Protein (g)': 16.0,
#   'Fat (g)': 22.0,
#   'Carbs (g)': 9,
#   'Sugar (g)': 15,
#   'Sodium (g)': 0.78,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Roast Beef',
#   'Cost (USD)': 8.78,
#   'Calories': 140,
#   'Protein (g)': 3.5,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.46,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Rotisserie-Style Chicken',
#   'Cost (USD)': 7.78,
#   'Calories': 170,
#   'Protein (g)': 5.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 23,
#   'Sodium (g)': 0.36,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Steak & Cheese',
#   'Cost (USD)': 8.78,
#   'Calories': 200,
#   'Protein (g)': 9.0,
#   'Fat (g)': 13.0,
#   'Carbs (g)': 7,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.83,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Steak Club Salad',
#   'Cost (USD)': 7.99,
#   'Calories': 480,
#   'Protein (g)': 26.0,
#   'Fat (g)': 21.0,
#   'Carbs (g)': 9,
#   'Sugar (g)': 44,
#   'Sodium (g)': 2.05,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Subway Club®',
#   'Cost (USD)': 8.78,
#   'Calories': 140,
#   'Protein (g)': 3.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.61,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Sweet Onion Chicken Teriyaki',
#   'Cost (USD)': 7.78,
#   'Calories': 210,
#   'Protein (g)': 3.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 21,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.62,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Tuna',
#   'Cost (USD)': 7.78,
#   'Calories': 310,
#   'Protein (g)': 24.0,
#   'Fat (g)': 10.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 15,
#   'Sodium (g)': 0.37,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Turkey Breast',
#   'Cost (USD)': 7.78,
#   'Calories': 110,
#   'Protein (g)': 2.0,
#   'Fat (g)': 11.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 14,
#   'Sodium (g)': 0.52,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Salad',
#   'Items': 'Veggie Delite®',
#   'Cost (USD)': 5.98,
#   'Calories': 50,
#   'Protein (g)': 1.0,
#   'Fat (g)': 9.0,
#   'Carbs (g)': 5,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.075,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Breakfast',
#   'Items': 'Bacon, Egg & Cheese',
#   'Cost (USD)': 4.29,
#   'Calories': 450,
#   'Protein (g)': 20.0,
#   'Fat (g)': 45.0,
#   'Carbs (g)': 4,
#   'Sugar (g)': 24,
#   'Sodium (g)': 1.2,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Breakfast',
#   'Items': 'Black Forest Ham, Egg & Cheese',
#   'Cost (USD)': 4.29,
#   'Calories': 410,
#   'Protein (g)': 16.0,
#   'Fat (g)': 45.0,
#   'Carbs (g)': 4,
#   'Sugar (g)': 24,
#   'Sodium (g)': 1.18,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Breakfast',
#   'Items': 'Egg & Cheese',
#   'Cost (USD)': 3.99,
#   'Calories': 380,
#   'Protein (g)': 15.0,
#   'Fat (g)': 44.0,
#   'Carbs (g)': 3,
#   'Sugar (g)': 19,
#   'Sodium (g)': 0.95,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Breakfast',
#   'Items': 'Steak, Egg & Cheese',
#   'Cost (USD)': 4.29,
#   'Calories': 440,
#   'Protein (g)': 18.0,
#   'Fat (g)': 46.0,
#   'Carbs (g)': 4,
#   'Sugar (g)': 27,
#   'Sodium (g)': 1.27,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Caramel Apple Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 210,
#   'Protein (g)': 6.0,
#   'Fat (g)': 37.0,
#   'Carbs (g)': 26,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.065,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Chocolate Chip Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 210,
#   'Protein (g)': 10.0,
#   'Fat (g)': 29.0,
#   'Carbs (g)': 18,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.12,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Chocolate Chip with M&M',
#   'Cost (USD)': 0.6,
#   'Calories': 210,
#   'Protein (g)': 10.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 18,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Chocolate Chunk Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 210,
#   'Protein (g)': 10.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 17,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Dark Chocolate Cherry Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 200,
#   'Protein (g)': 8.0,
#   'Fat (g)': 33.0,
#   'Carbs (g)': 24,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Double Chocolate',
#   'Cost (USD)': 0.6,
#   'Calories': 210,
#   'Protein (g)': 9.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 20,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.13,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Oatmeal Raisin Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 200,
#   'Protein (g)': 8.0,
#   'Fat (g)': 30.0,
#   'Carbs (g)': 16,
#   'Sugar (g)': 3,
#   'Sodium (g)': 0.13,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Raspberry Cheesecake Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 200,
#   'Protein (g)': 9.0,
#   'Fat (g)': 29.0,
#   'Carbs (g)': 16,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.12,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Raspberry Lemonade Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 230,
#   'Protein (g)': 11.0,
#   'Fat (g)': 31.0,
#   'Carbs (g)': 20,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.1,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'Sugar Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 230,
#   'Protein (g)': 12.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 14,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.13,
#   'quantity': 1},
#  {'Restaurant': 'subway',
#   'Category': 'Dessert',
#   'Items': 'White Chip Macadamia Nut Cookie',
#   'Cost (USD)': 0.6,
#   'Calories': 220,
#   'Protein (g)': 11.0,
#   'Fat (g)': 28.0,
#   'Carbs (g)': 17,
#   'Sugar (g)': 2,
#   'Sodium (g)': 0.13,
#   'quantity': 1}]

# %%
px.bar(g1[test], x="Items", y="Cost (USD)", 
                 color="Restaurant", barmode="group")
